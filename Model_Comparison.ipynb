# %%
import matplotlib.pyplot as plt

# %%
bars = plt.bar(["Random", "Heuristic", "Heuristic-KNN", "Heuristic-RF", "Human_RF", "Sean's DQN", "Michael's DQN"], [0, 0.583, 0.006, 0.007, 0.016, 0.3495, 0.121])
plt.ylabel("Average Lines Cleared")
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height,  # position
             f'{height}', ha='center', va='bottom')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Random'),
#   Text(1, 0, 'Heuristic'),
#   Text(2, 0, 'Heuristic-KNN'),
#   Text(3, 0, 'Heuristic-RF'),
#   Text(4, 0, 'Human_RF'),
#   Text(5, 0, "Sean's DQN"),
#   Text(6, 0, "Michael's DQN")])

# %%
plt.bar(["Random", "Heuristic", "Human"], [0, 0.058])
plt.ylabel("Average Lines Cleared")
plt.xticks(rotation=45)
