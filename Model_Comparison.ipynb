# %%
import matplotlib.pyplot as plt

# %%
plt.bar(["Random", "Heuristic", "Heuristic-KNN", "Heuristic-RF", "Human_RF", "Sean's DQN"], [0, 0.583, 0.006, 0.007, 0.016, 0.319])
plt.ylabel("Average Lines Cleared")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Random'),
#   Text(1, 0, 'Heuristic'),
#   Text(2, 0, 'Heuristic-KNN'),
#   Text(3, 0, 'Heuristic-RF'),
#   Text(4, 0, 'Human_RF'),
#   Text(5, 0, "Sean's DQN")])

# %%
plt.bar(["Random", "Heuristic", "Human"], [0, 0.058])
plt.ylabel("Average Lines Cleared")
plt.xticks(rotation=45)
